# %% [markdown]
# ##Python Değişkenler

# %%
print("Hello TechIstanbul")
# Out:
# Hello TechIstanbul

# %%
x = 5 # İnteger - int Tam sayı
y = 5.9 #float Kesirli sayı
z = "5" # String - str Karakter - Semboller

Battal_1 = str(x+y)

# %%
print(type(Battal_1))
# Out:
# <class 'str'>

# %% [markdown]
# ##Örnekler

# %%
a = "Kullanıcı Adı"
b = "Şifre"
c = "Doğum Tarihi"

# %%
print(a,b,c, sep="\n", end="\n")
# Out:
# Kullanıcı Adı
# Şifre
# Doğum Tarihi

# %%
print("Battal",end="\n")
print("Koç")
# Out:
# Battal
# Koç

# %%
print("""
Battal
Koç

""")
# Out:
# Battal
# Koç

# %%
isim = "Mehmet"
soy_isim = "Koç"
hobi = "Bilgisayar oyunları oynamak."
felsefe = "Hayat sevince güzel."
soy_isim = input("Soy Adınız : ")
hobi = input("Hobileriniz : ")
felsefe = input("Felsefe : ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1482/2676218977.py in <cell line: 0>()
#       3 hobi = "Bilgisayar oyunları oynamak."
#       4 felsefe = "Hayat sevince güzel."
# ----> 5 soy_isim = input("Soy Adınız : ")
#       6 hobi = input("Hobileriniz : ")
#       7 felsefe = input("Felsefe : ")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
isim = input("Adınız : ")


print("Adınızın",isim,"olduğuna emin misiniz?")

# %%
print("İsim            :",isim)
print("Soy İsim        :",soy_isim)
print("Hobileri        :",hobi)
print("Hayat Felsefesi :",felsefe)

# %% [markdown]
# ##Hesap Makinası

# %%
sayi_1 = float(input("Sayı : "))
sembol = input("Yapılacak işlem : ")
sayi_2 = float(input("Sayı : "))

if sembol == "+":
  print(sayi_1+sayi_2)
elif sembol=="-":
  print(sayi_1-sayi_2)
elif sembol=="*":
  print(sayi_1*sayi_2)
elif sembol=="/":
  print(sayi_1/sayi_2)
else:
  print("Hatalı işlem yaptınız.")
# Out:
# Sayı : 10
# Yapılacak işlem : battal
# Sayı : 10
# Hatalı işlem yaptınız.

# %% [markdown]
# ##Hesaba giriş uygulaması

# %%
kullanici_adi = input("Kullanıcı adı : ")
sifre = input("Şifre : ")

belirlenmis_kullanici_adi = "battalkoc"
belirlenmis_sifre = "Python"

if belirlenmis_kullanici_adi != kullanici_adi or belirlenmis_sifre != sifre:
  print("Kullanıcı adınız veya şifreniz hatalı!")
else:
  print("Giriş başarılı!")
# Out:
# Kullanıcı adı : battalkoc
# Şifre : Python
# Giriş başarılı!

# %% [markdown]
# ##Belge Hesaplama Aracı

# %%
ögrencinin_notu = float(input("Lütfen notunuzu giriniz : "))

if ögrencinin_notu >= 85 and ögrencinin_notu <=100:
  print("Takdir belgesi almaya hak kazandınız.")
elif ögrencinin_notu >=70 and ögrencinin_notu < 85:
  print("Teşekkür belgesi almaya hak kazandınız.")
elif ögrencinin_notu < 70 and ögrencinin_notu >= 45:
  print("Belgesiz sınıfı geçtiniz.")
elif ögrencinin_notu < 45 and ögrencinin_notu >= 0:
  print("Sınıfta kaldınız.")
else:
  print("Hatalı değer girdiniz.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1482/1221812687.py in <cell line: 0>()
# ----> 1 ögrencinin_notu = float(input("Lütfen notunuzu giriniz : "))
#       2
#       3 if ögrencinin_notu >= 85 and ögrencinin_notu <=100:
#       4   print("Takdir belgesi almaya hak kazandınız.")
#       5 elif ögrencinin_notu >=70 and ögrencinin_notu < 85:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
